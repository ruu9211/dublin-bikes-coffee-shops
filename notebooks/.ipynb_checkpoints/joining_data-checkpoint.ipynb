# %% [markdown]
# Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
import pandas as pd
df_dublin = pd.read_csv('/Users/ruu/documents/LHL/Project-Statistical-Modelling/data/dublin_bikes.csv')
df_yelp = pd.read_csv('/Users/ruu/documents/LHL/Project-Statistical-Modelling/data/yelp.csv',index_col=0)

# Check df_yelp for any nulls, duplicates, for zero values that wouldn't make sense in a certain attribute:
df_yelp.isnull().sum()             # Only the address attribute has 23 null values observed, however, this wouldn't have an impact on our data set for the analysis we are conducting
df_yelp.duplicated().sum()         # No duplicates observed in our dataframe for every row
(df_yelp['rating']==0).sum()       # The rating attribute has 450 coffee shops with a rating of zero. This does not make sense because the rating scale typically on yelp is 1-5. These zero ratings could potentially mean that these shops have not been reviewed and rated by customers. Therefore, since this data can skew our analysis, we will be filtering out the zero rated coffee shops
(df_yelp['distance'] ==0).sum()    # No zero values observed

prct_zero_rating = (df_yelp['rating']==0).sum()/len(df_yelp)  # Around 11% of our dataset has a rating of 0 which is insignificant, therefore can be filtered out for our analysis

# Filter out the coffee shops with a rating of zero
df_yelp = df_yelp[df_yelp['rating'] >= 1.0]

# Grouping df_yelp by the coordinates and calculating aggregate values
df_agg = df_yelp.groupby(['bike_lat','bike_lon']).agg(num_shops=('name','count'),avg_rating=('rating','mean'), min_distance=('distance','min'))

# Merging df_agg and df_dublin together using the coordinates as the keys
df_final = pd.merge(df_dublin, df_agg, left_on=['latitude','longitude'], right_on=['bike_lat','bike_lon'], how='inner')
df_final.head(10)
# Out:
#     latitude  longitude                              names  num_bike_slots  \
# 0  53.354929  -6.269425                        WESTERN WAY              40
# 1  53.349013  -6.260311  PRINCES STREET / O'CONNELL STREET              23
# 2  53.336074  -6.252825            FITZWILLIAM SQUARE WEST              30
# 3  53.351182  -6.269859                      BOLTON STREET              20
# 4  53.354663  -6.278681         GRANGEGORMAN LOWER (SOUTH)              40
# 5  53.347692  -6.278214                         SMITHFIELD              30
# 6  53.338755  -6.262003                   YORK STREET EAST              32
# 7  53.340927  -6.262501                      CLARENDON ROW              31
# 8  53.358115  -6.265601                 ECCLES STREET EAST              27
# 9  53.350291  -6.273507                  KING STREET NORTH              30
#
#    num_shops  avg_rating  min_distance
# 0         21    3.633333    209.920901
# 1         50    4.142000     50.119272
# ...

# %%
# Saving the df_final dataframe as .csv
df_final.to_csv('final_combined.csv')

# %% [markdown]
# Provide a visualization that you used as part of your EDA process. Explain the initial pattern or relationship you discoved through this visualization.

# %% [markdown]
# A series of scatter plots were created to explore potential relationships between the dependent variable (number of bikes at each station) and the independent variables (number of nearby coffee shops within 350m radius, average coffee shop rating, and the minimum distance to the nearest coffee shop in meters). The visualizations did not reveal any clear patterns or trends, indicating no apparent linear relationship between the variables. Based on the visualizations, it looks like the correlation cofficient (r) for each pairing is likely zero.

# %%
import matplotlib.pyplot as plt
plt.scatter(df_final['num_shops'], df_final['num_bike_slots'])
plt.xlabel('Number of Coffee Shops')
plt.ylabel('Number of Bike Slots')
plt.title('Relationship Between Nearby Coffee Shops and Station Capacity')
# Out:
# Text(0.5, 1.0, 'Relationship Between Nearby Coffee Shops and Station Capacity')

# %%
import matplotlib.pyplot as plt
plt.scatter(df_final['avg_rating'], df_final['num_bike_slots'])
plt.xlabel('Average Rating of Coffee Shops')
plt.ylabel('Number of Bike Slots')
plt.title('Relationship Between Coffee Shop Ratings and Station Capacity')
# Out:
# Text(0.5, 1.0, 'Relationship Between Coffee Shop Ratings and Station Capacity')

# %%
import matplotlib.pyplot as plt
plt.scatter(df_final['min_distance'], df_final['num_bike_slots'])
plt.xlabel('Min Distance to a Coffee Shop (m)')
plt.ylabel('Number of Bike Slots')
plt.title('Relationship Between Distance to Nearest Coffee Shop and Station Capacity')
# Out:
# Text(0.5, 1.0, 'Relationship Between Distance to Nearest Coffee Shop and Station Capacity')

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect('/Users/ruu/documents/LHL/Project-Statistical-Modelling/data/project_2.db')

df_agg.to_sql(name='yelp_agg', con=conn, if_exists='replace',index=True)
df_dublin.to_sql(name='dublin', con=conn, if_exists='replace',index=False)
# Out:
# 115

# %% [markdown]
# Look at the data before and after the join to validate your data.

# %%
# Number of rows in df_dublin and df_agg from before the join are identical
print(pd.read_sql('SELECT COUNT(*) AS total_rows FROM dublin;', conn))
print(pd.read_sql('SELECT COUNT(*) AS total_rows FROM yelp_agg;', conn))
# Out:
#    total_rows
# 0         115
#    total_rows
# 0         115

# %%
# Data after the join are also identical - filtered final join to view 10 observations. 
query = """
SELECT  d.latitude, 
        d.longitude, 
        d.num_bike_slots,
        d.names,
        y.num_shops,
        y.avg_rating, 
        y.min_distance
FROM    yelp_agg as y
        JOIN dublin as d
        ON d.latitude=y.bike_lat AND d.longitude=y.bike_lon
LIMIT   10
;
"""
print(pd.read_sql(query, conn))
# Out:
#     latitude  longitude  num_bike_slots                              names  \
# 0  53.354929  -6.269425              40                        WESTERN WAY
# 1  53.349013  -6.260311              23  PRINCES STREET / O'CONNELL STREET
# 2  53.336074  -6.252825              30            FITZWILLIAM SQUARE WEST
# 3  53.351182  -6.269859              20                      BOLTON STREET
# 4  53.354663  -6.278681              40         GRANGEGORMAN LOWER (SOUTH)
# 5  53.347692  -6.278214              30                         SMITHFIELD
# 6  53.338755  -6.262003              32                   YORK STREET EAST
# 7  53.340927  -6.262501              31                      CLARENDON ROW
# 8  53.358115  -6.265601              27                 ECCLES STREET EAST
# 9  53.350291  -6.273507              30                  KING STREET NORTH
#
#    num_shops  avg_rating  min_distance
# 0         21    3.633333    209.920901
# 1         50    4.142000     50.119272
# ...

# %%
conn.close()
