# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import requests

# Selecting Dublin, Ireland as the city of choice
network_id = 'dublinbikes'
url = 'http://api.citybik.es/v2/networks/' + network_id
dublin_network_json = requests.get(url).json()
# Out:
# /opt/anaconda3/envs/pandas_env/lib/python3.9/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
# Assigning total_network variable to our dublin city bikes dataset
total_network = dublin_network_json['network']['stations']
total_network

# Parsing through the response to obtain name (as id), longitude, latitude, and number of bikes as total slots (i.e. total capacity) in a particular station
#names = [station['name']for station in total_network]
#longitude = [station['longitude']for station in total_network]
#latitude = [station['latitude']for station in total_network]
#num_bike_slots = [station['extra']['slots']for station in total_network]
# Out:
# [{'id': '00fdf0f8415ac09af8709303f5dd419d',
#   'name': 'WESTERN WAY',
#   'latitude': 53.354929,
#   'longitude': -6.269425,
#   'timestamp': '2025-07-26T19:39:45.212913+00:00Z',
#   'free_bikes': 1,
#   'empty_slots': 39,
#   'extra': {'uid': 102,
#    'address': 'Western Way',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:24Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 1}},
#  {'id': '01908efd6badf1c9cf37f1fb62160bbd',
#   'name': "PRINCES STREET / O'CONNELL STREET",
#   'latitude': 53.349013,
#   'longitude': -6.260311,
#   'timestamp': '2025-07-26T19:39:45.213184+00:00Z',
#   'free_bikes': 20,
#   'empty_slots': 3,
#   'extra': {'uid': 33,
#    'address': "Princes Street / O'Connell Street",
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:26Z',
#    'slots': 23,
#    'has_ebikes': True,
#    'ebikes': 5,
#    'normal_bikes': 15}},
#  {'id': '03a129962208387e736a8305ff928dfe',
#   'name': 'FITZWILLIAM SQUARE WEST',
#   'latitude': 53.336074,
#   'longitude': -6.252825,
#   'timestamp': '2025-07-26T19:39:45.212707+00:00Z',
#   'free_bikes': 1,
#   'empty_slots': 29,
#   'extra': {'uid': 13,
#    'address': 'Fitzwilliam Square West',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:35:47Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 1}},
#  {'id': '05280ab89efb0433301353fd0b73b054',
#   'name': 'BOLTON STREET',
#   'latitude': 53.351182,
#   'longitude': -6.269859,
#   'timestamp': '2025-07-26T19:39:45.213217+00:00Z',
#   'free_bikes': 20,
#   'empty_slots': 0,
#   'extra': {'uid': 3,
#    'address': 'Bolton Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:26Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 15,
#    'normal_bikes': 5}},
#  {'id': '09db22de8548b15120cdb7a4b18a0937',
#   'name': 'GRANGEGORMAN LOWER (SOUTH)',
#   'latitude': 53.354663,
#   'longitude': -6.278681,
#   'timestamp': '2025-07-26T19:39:45.213238+00:00Z',
#   'free_bikes': 7,
#   'empty_slots': 33,
#   'extra': {'uid': 103,
#    'address': 'Grangegorman Lower (South)',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:26Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 3,
#    'normal_bikes': 4}},
#  {'id': '0bd08b069605f316a1223da35b19543d',
#   'name': 'SMITHFIELD',
#   'latitude': 53.347692,
#   'longitude': -6.278214,
#   'timestamp': '2025-07-26T19:39:45.213140+00:00Z',
#   'free_bikes': 6,
#   'empty_slots': 24,
#   'extra': {'uid': 35,
#    'address': 'Smithfield',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:33:01Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 2,
#    'normal_bikes': 4}},
#  {'id': '0c34fb0af6d2b20fe458d5fef1150854',
#   'name': 'YORK STREET EAST',
#   'latitude': 53.338755,
#   'longitude': -6.262003,
#   'timestamp': '2025-07-26T19:39:45.212695+00:00Z',
#   'free_bikes': 21,
#   'empty_slots': 11,
#   'extra': {'uid': 52,
#    'address': 'York Street East',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:30Z',
#    'slots': 32,
#    'has_ebikes': True,
#    'ebikes': 3,
#    'normal_bikes': 18}},
#  {'id': '0db5e763ba7f51ccdac0c86b7252432f',
#   'name': 'CLARENDON ROW',
#   'latitude': 53.340927,
#   'longitude': -6.262501,
#   'timestamp': '2025-07-26T19:39:45.212734+00:00Z',
#   'free_bikes': 20,
#   'empty_slots': 11,
#   'extra': {'uid': 1,
#    'address': 'Clarendon Row',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:41Z',
#    'slots': 31,
#    'has_ebikes': True,
#    'ebikes': 8,
#    'normal_bikes': 12}},
#  {'id': '0df9de93015a6cbbe7e505075ca67b88',
#   'name': 'ECCLES STREET EAST',
#   'latitude': 53.358115,
#   'longitude': -6.265601,
#   'timestamp': '2025-07-26T19:39:45.213009+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 27,
#   'extra': {'uid': 79,
#    'address': 'Eccles Street East',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:36Z',
#    'slots': 27,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': '0e810897bfa0ec6bb84a6ed4cbef236f',
#   'name': 'KING STREET NORTH',
#   'latitude': 53.350291,
#   'longitude': -6.273507,
#   'timestamp': '2025-07-26T19:39:45.212947+00:00Z',
#   'free_bikes': 12,
#   'empty_slots': 18,
#   'extra': {'uid': 101,
#    'address': 'King Street North',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:35:43Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 5,
#    'normal_bikes': 7}},
#  {'id': '0f8feb0dc54ee559f1517c597e284663',
#   'name': 'BENSON STREET',
#   'latitude': 53.344153,
#   'longitude': -6.233451,
#   'timestamp': '2025-07-26T19:39:45.212778+00:00Z',
#   'free_bikes': 8,
#   'empty_slots': 32,
#   'extra': {'uid': 90,
#    'address': 'Benson Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:30Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 4,
#    'normal_bikes': 4}},
#  {'id': '0f9fa036045d6af51bfa8e2e39188966',
#   'name': 'GRANGEGORMAN LOWER (CENTRAL)',
#   'latitude': 53.355173,
#   'longitude': -6.278424,
#   'timestamp': '2025-07-26T19:39:45.212941+00:00Z',
#   'free_bikes': 14,
#   'empty_slots': 26,
#   'extra': {'uid': 104,
#    'address': 'Grangegorman Lower (Central)',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:14Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 8,
#    'normal_bikes': 6}},
#  {'id': '11b359924d83d802a41856c405d13e61',
#   'name': 'ROTHE ABBEY',
#   'latitude': 53.338776,
#   'longitude': -6.30395,
#   'timestamp': '2025-07-26T19:39:45.213173+00:00Z',
#   'free_bikes': 24,
#   'empty_slots': 11,
#   'extra': {'uid': 85,
#    'address': 'Rothe Abbey',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:02Z',
#    'slots': 35,
#    'has_ebikes': True,
#    'ebikes': 11,
#    'normal_bikes': 13}},
#  {'id': '135d1f3410c5dbcc49c55a1d522dbbe6',
#   'name': 'CITY QUAY',
#   'latitude': 53.346637,
#   'longitude': -6.246154,
#   'timestamp': '2025-07-26T19:39:45.212827+00:00Z',
#   'free_bikes': 1,
#   'empty_slots': 29,
#   'extra': {'uid': 99,
#    'address': 'City Quay',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:48Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 1}},
#  {'id': '13b5177c9d64d6cb8072f680addbf274',
#   'name': 'CLONMEL STREET',
#   'latitude': 53.336021,
#   'longitude': -6.26298,
#   'timestamp': '2025-07-26T19:39:45.212654+00:00Z',
#   'free_bikes': 10,
#   'empty_slots': 23,
#   'extra': {'uid': 54,
#    'address': 'Clonmel Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:16Z',
#    'slots': 33,
#    'has_ebikes': True,
#    'ebikes': 3,
#    'normal_bikes': 7}},
#  {'id': '153ff4dfb7bd8912ef91c10849129c2e',
#   'name': 'FITZWILLIAM SQUARE EAST',
#   'latitude': 53.335211,
#   'longitude': -6.2509,
#   'timestamp': '2025-07-26T19:39:45.213195+00:00Z',
#   'free_bikes': 1,
#   'empty_slots': 39,
#   'extra': {'uid': 89,
#    'address': 'Fitzwilliam Square East',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:30:28Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 1,
#    'normal_bikes': 0}},
#  {'id': '163b271b79135baced85e8b3d02c9726',
#   'name': 'EARLSFORT TERRACE',
#   'latitude': 53.334295,
#   'longitude': -6.258503,
#   'timestamp': '2025-07-26T19:39:45.212783+00:00Z',
#   'free_bikes': 1,
#   'empty_slots': 29,
#   'extra': {'uid': 11,
#    'address': 'Earlsfort Terrace',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:38Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 1}},
#  {'id': '1d00b2d8a2c6e87fe5bce251bf05f2f8',
#   'name': 'PEARSE STREET',
#   'latitude': 53.344304,
#   'longitude': -6.250427,
#   'timestamp': '2025-07-26T19:39:45.212689+00:00Z',
#   'free_bikes': 14,
#   'empty_slots': 16,
#   'extra': {'uid': 32,
#    'address': 'Pearse Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:39Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 7,
#    'normal_bikes': 7}},
#  {'id': '1f233a084b541e2f3b2449e7bdcb70d7',
#   'name': 'JAMES STREET EAST',
#   'latitude': 53.336597,
#   'longitude': -6.248109,
#   'timestamp': '2025-07-26T19:39:45.212666+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 30,
#   'extra': {'uid': 20,
#    'address': 'James Street East',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:01Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': '1ff69df9ba513f13683792c5824f1fc8',
#   'name': 'JOHN STREET WEST',
#   'latitude': 53.343105,
#   'longitude': -6.277167,
#   'timestamp': '2025-07-26T19:39:45.212805+00:00Z',
#   'free_bikes': 11,
#   'empty_slots': 20,
#   'extra': {'uid': 72,
#    'address': 'John Street West',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:01Z',
#    'slots': 31,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 11}},
#  {'id': '23b52025656abda6ce66359eced63f7f',
#   'name': 'EXCISE WALK',
#   'latitude': 53.347777,
#   'longitude': -6.244239,
#   'timestamp': '2025-07-26T19:39:45.212701+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 40,
#   'extra': {'uid': 48,
#    'address': 'Excise Walk',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:35:45Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': '24c29a574f6850ee7bfaf48d926e1bbb',
#   'name': 'MOUNTJOY SQUARE EAST',
#   'latitude': 53.356717,
#   'longitude': -6.256359,
#   'timestamp': '2025-07-26T19:39:45.213113+00:00Z',
#   'free_bikes': 2,
#   'empty_slots': 38,
#   'extra': {'uid': 111,
#    'address': 'Mountjoy Square East',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:33:58Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 2}},
#  {'id': '250660fe6d0e479bd0bf3681286bbac4',
#   'name': 'KILMAINHAM LANE',
#   'latitude': 53.341805,
#   'longitude': -6.305085,
#   'timestamp': '2025-07-26T19:39:45.212986+00:00Z',
#   'free_bikes': 3,
#   'empty_slots': 27,
#   'extra': {'uid': 96,
#    'address': 'Kilmainham Lane',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:10Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 3}},
#  {'id': '2507ed763f57e32fdfce219ee90019db',
#   'name': 'FRANCIS STREET',
#   'latitude': 53.342081,
#   'longitude': -6.275233,
#   'timestamp': '2025-07-26T19:39:45.212881+00:00Z',
#   'free_bikes': 15,
#   'empty_slots': 15,
#   'extra': {'uid': 73,
#    'address': 'Francis Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:22Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 6,
#    'normal_bikes': 9}},
#  {'id': '26abc58b27ae800ff23d6b82e0e11ef5',
#   'name': 'GRATTAN STREET',
#   'latitude': 53.339629,
#   'longitude': -6.243778,
#   'timestamp': '2025-07-26T19:39:45.213201+00:00Z',
#   'free_bikes': 9,
#   'empty_slots': 14,
#   'extra': {'uid': 57,
#    'address': 'Grattan Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:35:03Z',
#    'slots': 23,
#    'has_ebikes': True,
#    'ebikes': 6,
#    'normal_bikes': 3}},
#  {'id': '279a7a5d9e07d50528ff6479df92b3fb',
#   'name': 'HIGH STREET',
#   'latitude': 53.343565,
#   'longitude': -6.275071,
#   'timestamp': '2025-07-26T19:39:45.212902+00:00Z',
#   'free_bikes': 19,
#   'empty_slots': 10,
#   'extra': {'uid': 7,
#    'address': 'High Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:39Z',
#    'slots': 29,
#    'has_ebikes': True,
#    'ebikes': 4,
#    'normal_bikes': 15}},
#  {'id': '309e2bc421c732ddb1dc59f2e28cebe2',
#   'name': 'MERRION SQUARE EAST',
#   'latitude': 53.339434,
#   'longitude': -6.246548,
#   'timestamp': '2025-07-26T19:39:45.213019+00:00Z',
#   'free_bikes': 2,
#   'empty_slots': 28,
#   'extra': {'uid': 25,
#    'address': 'Merrion Square East',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:51Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 2,
#    'normal_bikes': 0}},
#  {'id': '33030fc55807ba8703db9da20ac87616',
#   'name': 'HARCOURT TERRACE',
#   'latitude': 53.332763,
#   'longitude': -6.257942,
#   'timestamp': '2025-07-26T19:39:45.213211+00:00Z',
#   'free_bikes': 2,
#   'empty_slots': 18,
#   'extra': {'uid': 41,
#    'address': 'Harcourt Terrace',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:37Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 1,
#    'normal_bikes': 1}},
#  {'id': '33676fd7a00d95b12a0b24425900caaa',
#   'name': 'HEUSTON BRIDGE (NORTH)',
#   'latitude': 53.347802,
#   'longitude': -6.292432,
#   'timestamp': '2025-07-26T19:39:45.213260+00:00Z',
#   'free_bikes': 37,
#   'empty_slots': 3,
#   'extra': {'uid': 92,
#    'address': 'Heuston Bridge (North)',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:43Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 12,
#    'normal_bikes': 25}},
#  {'id': '381519659470772b8e6373137aa54ed0',
#   'name': 'LEINSTER STREET SOUTH',
#   'latitude': 53.34218,
#   'longitude': -6.254485,
#   'timestamp': '2025-07-26T19:39:45.213265+00:00Z',
#   'free_bikes': 14,
#   'empty_slots': 16,
#   'extra': {'uid': 21,
#    'address': 'Leinster Street South',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:07Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 7,
#    'normal_bikes': 7}},
#  {'id': '39bef75a632e11c0fc34f95624e5c122',
#   'name': 'GRANGEGORMAN LOWER (NORTH)',
#   'latitude': 53.355954,
#   'longitude': -6.278378,
#   'timestamp': '2025-07-26T19:39:45.213052+00:00Z',
#   'free_bikes': 2,
#   'empty_slots': 34,
#   'extra': {'uid': 105,
#    'address': 'Grangegorman Lower (North)',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:50Z',
#    'slots': 36,
#    'has_ebikes': True,
#    'ebikes': 1,
#    'normal_bikes': 1}},
#  {'id': '3c0cfd547a142bb651280991a412bcbe',
#   'name': 'PORTOBELLO HARBOUR',
#   'latitude': 53.330362,
#   'longitude': -6.265163,
#   'timestamp': '2025-07-26T19:39:45.213091+00:00Z',
#   'free_bikes': 2,
#   'empty_slots': 28,
#   'extra': {'uid': 34,
#    'address': 'Portobello Harbour',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:11Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 2,
#    'normal_bikes': 0}},
#  {'id': '424686745b03bf79a129185f0d9e8f31',
#   'name': 'THE POINT',
#   'latitude': 53.346867,
#   'longitude': -6.230852,
#   'timestamp': '2025-07-26T19:39:45.212838+00:00Z',
#   'free_bikes': 26,
#   'empty_slots': 14,
#   'extra': {'uid': 67,
#    'address': 'The Point',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:35:54Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 7,
#    'normal_bikes': 19}},
#  {'id': '427f01fdc89a9e4156f70c7810784bc1',
#   'name': 'GEORGES QUAY',
#   'latitude': 53.347508,
#   'longitude': -6.252192,
#   'timestamp': '2025-07-26T19:39:45.212981+00:00Z',
#   'free_bikes': 17,
#   'empty_slots': 3,
#   'extra': {'uid': 16,
#    'address': 'Georges Quay',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:35:06Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 12,
#    'normal_bikes': 5}},
#  {'id': '428424092e82ea61a70490dfc9211819',
#   'name': 'BROADSTONE',
#   'latitude': 53.3547,
#   'longitude': -6.272314,
#   'timestamp': '2025-07-26T19:39:45.212843+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 30,
#   'extra': {'uid': 116,
#    'address': 'Broadstone',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:11Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': '43060a5abcbb254aed204872da5b300f',
#   'name': 'HEUSTON STATION (CAR PARK)',
#   'latitude': 53.346985,
#   'longitude': -6.297804,
#   'timestamp': '2025-07-26T19:39:45.213047+00:00Z',
#   'free_bikes': 28,
#   'empty_slots': 12,
#   'extra': {'uid': 94,
#    'address': 'Heuston Station (Car Park)',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:33Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 12,
#    'normal_bikes': 16}},
#  {'id': '43819587f9f674e70910a8a04ba222bd',
#   'name': 'PARNELL SQUARE NORTH',
#   'latitude': 53.3537415547453,
#   'longitude': -6.26530144781526,
#   'timestamp': '2025-07-26T19:39:45.212646+00:00Z',
#   'free_bikes': 1,
#   'empty_slots': 19,
#   'extra': {'uid': 30,
#    'address': 'Parnell Square North',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:30Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 1,
#    'normal_bikes': 0}},
#  {'id': '45918c3c3aefd7503768a69654b2673a',
#   'name': 'PARNELL STREET',
#   'latitude': 53.350929,
#   'longitude': -6.265125,
#   'timestamp': '2025-07-26T19:39:45.212717+00:00Z',
#   'free_bikes': 19,
#   'empty_slots': 1,
#   'extra': {'uid': 31,
#    'address': 'Parnell Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:48Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 11,
#    'normal_bikes': 8}},
#  {'id': '4592d38c6267eee141a2ab5feb049765',
#   'name': 'AVONDALE ROAD',
#   'latitude': 53.359405,
#   'longitude': -6.276142,
#   'timestamp': '2025-07-26T19:39:45.212660+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 35,
#   'extra': {'uid': 108,
#    'address': 'Avondale Road',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:10Z',
#    'slots': 35,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': '49ac0f7be439341005b8113957bdb7b7',
#   'name': 'YORK STREET WEST',
#   'latitude': 53.339334,
#   'longitude': -6.264699,
#   'timestamp': '2025-07-26T19:39:45.213025+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 0,
#   'extra': {'uid': 51,
#    'address': 'York Street West',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:33:09Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': '49d8c36b00f1581cc9ca2fe1b87b7a5a',
#   'name': 'DAME STREET',
#   'latitude': 53.344007,
#   'longitude': -6.266802,
#   'timestamp': '2025-07-26T19:39:45.213146+00:00Z',
#   'free_bikes': 16,
#   'empty_slots': 0,
#   'extra': {'uid': 10,
#    'address': 'Dame Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:13Z',
#    'slots': 16,
#    'has_ebikes': True,
#    'ebikes': 3,
#    'normal_bikes': 13}},
#  {'id': '4d01aeaab7d37c25b090856eefcc354c',
#   'name': 'CHARLEMONT PLACE',
#   'latitude': 53.330662,
#   'longitude': -6.260177,
#   'timestamp': '2025-07-26T19:39:45.212859+00:00Z',
#   'free_bikes': 27,
#   'empty_slots': 13,
#   'extra': {'uid': 5,
#    'address': 'Charlemont Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:25Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 18,
#    'normal_bikes': 9}},
#  {'id': '4f95382153a0f7817256a5d175525f13',
#   'name': 'HANOVER QUAY EAST',
#   'latitude': 53.343653,
#   'longitude': -6.231755,
#   'timestamp': '2025-07-26T19:39:45.212963+00:00Z',
#   'free_bikes': 4,
#   'empty_slots': 36,
#   'extra': {'uid': 117,
#    'address': 'Hanover Quay East',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:43Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 3,
#    'normal_bikes': 1}},
#  {'id': '5169be333974ddf2a5f9e22896cb95fa',
#   'name': 'PARKGATE STREET',
#   'latitude': 53.347972,
#   'longitude': -6.291804,
#   'timestamp': '2025-07-26T19:39:45.213134+00:00Z',
#   'free_bikes': 32,
#   'empty_slots': 5,
#   'extra': {'uid': 86,
#    'address': 'Parkgate Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:39Z',
#    'slots': 38,
#    'has_ebikes': True,
#    'ebikes': 13,
#    'normal_bikes': 19}},
#  {'id': '516ee41c56889c29b8fa5f4ac0e824f4',
#   'name': 'BROOKFIELD ROAD',
#   'latitude': 53.339005,
#   'longitude': -6.300217,
#   'timestamp': '2025-07-26T19:39:45.212772+00:00Z',
#   'free_bikes': 18,
#   'empty_slots': 12,
#   'extra': {'uid': 84,
#    'address': 'Brookfield Road',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:32Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 13,
#    'normal_bikes': 5}},
#  {'id': '545abfed174ff3eba9ee8adc12b33e68',
#   'name': 'TOWNSEND STREET',
#   'latitude': 53.345922,
#   'longitude': -6.254614,
#   'timestamp': '2025-07-26T19:39:45.213070+00:00Z',
#   'free_bikes': 20,
#   'empty_slots': 0,
#   'extra': {'uid': 22,
#    'address': 'Townsend Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:40Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 8,
#    'normal_bikes': 12}},
#  {'id': '54f426954f30de0045bfd0c3795885fd',
#   'name': 'ST JAMES HOSPITAL (LUAS)',
#   'latitude': 53.341359,
#   'longitude': -6.292951,
#   'timestamp': '2025-07-26T19:39:45.213206+00:00Z',
#   'free_bikes': 15,
#   'empty_slots': 25,
#   'extra': {'uid': 80,
#    'address': 'St James Hospital (Luas)',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:33:20Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 10,
#    'normal_bikes': 5}},
#  {'id': '56af00ad9631d36e6aa66697b718f9e0',
#   'name': 'SOUTH DOCK ROAD',
#   'latitude': 53.341833,
#   'longitude': -6.231291,
#   'timestamp': '2025-07-26T19:39:45.212821+00:00Z',
#   'free_bikes': 24,
#   'empty_slots': 6,
#   'extra': {'uid': 91,
#    'address': 'South Dock Road',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:47Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 9,
#    'normal_bikes': 15}},
#  {'id': '577db83eb19140b4f4a821bb93118e59',
#   'name': 'MOUNT STREET LOWER',
#   'latitude': 53.33796,
#   'longitude': -6.24153,
#   'timestamp': '2025-07-26T19:39:45.212671+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 40,
#   'extra': {'uid': 56,
#    'address': 'Mount Street Lower',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:29Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': '6141f2e7bed7b74a62c90855c3b95987',
#   'name': 'GEORGES LANE',
#   'latitude': 53.35023,
#   'longitude': -6.279696,
#   'timestamp': '2025-07-26T19:39:45.213075+00:00Z',
#   'free_bikes': 2,
#   'empty_slots': 38,
#   'extra': {'uid': 50,
#    'address': "George's Lane",
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:48Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 2}},
#  {'id': '633407d717379558361082872bf00e3c',
#   'name': 'BLESSINGTON STREET',
#   'latitude': 53.356769,
#   'longitude': -6.26814,
#   'timestamp': '2025-07-26T19:39:45.213102+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 20,
#   'extra': {'uid': 2,
#    'address': 'Blessington Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:35:51Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': '6637d89d1c9a28945ae2e00a170532e2',
#   'name': "SIR PATRICK DUN'S",
#   'latitude': 53.339218,
#   'longitude': -6.240642,
#   'timestamp': '2025-07-26T19:39:45.212930+00:00Z',
#   'free_bikes': 2,
#   'empty_slots': 38,
#   'extra': {'uid': 58,
#    'address': "Sir Patrick's Dun",
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:11Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 2,
#    'normal_bikes': 0}},
#  {'id': '665a1d9b2f88f5bced1a2ee49a99e937',
#   'name': 'NORTH CIRCULAR ROAD',
#   'latitude': 53.359624,
#   'longitude': -6.260348,
#   'timestamp': '2025-07-26T19:39:45.212908+00:00Z',
#   'free_bikes': 4,
#   'empty_slots': 26,
#   'extra': {'uid': 60,
#    'address': 'North Circular Road',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:31:32Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 4}},
#  {'id': '68a1b64209d3d6f8ddc9a449ce9e2d29',
#   'name': 'MOLESWORTH STREET',
#   'latitude': 53.341288,
#   'longitude': -6.258117,
#   'timestamp': '2025-07-26T19:39:45.212974+00:00Z',
#   'free_bikes': 12,
#   'empty_slots': 8,
#   'extra': {'uid': 27,
#    'address': 'Molesworth Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:07Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 7,
#    'normal_bikes': 5}},
#  {'id': '6bff19daf1747a1e956a899ef8021232',
#   'name': 'EMMET ROAD',
#   'latitude': 53.340714,
#   'longitude': -6.308191,
#   'timestamp': '2025-07-26T19:39:45.213254+00:00Z',
#   'free_bikes': 18,
#   'empty_slots': 22,
#   'extra': {'uid': 83,
#    'address': 'Emmet Road',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:35Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 9,
#    'normal_bikes': 9}},
#  {'id': '6f8f3c1c562ee09e6c33c8606137d72c',
#   'name': 'HARDWICKE PLACE',
#   'latitude': 53.357043,
#   'longitude': -6.263232,
#   'timestamp': '2025-07-26T19:39:45.212870+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 25,
#   'extra': {'uid': 61,
#    'address': 'Hardwicke Place',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:07Z',
#    'slots': 25,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': '703463670ff93e5b4dd4a2f452c597dc',
#   'name': 'MERRION SQUARE SOUTH',
#   'latitude': 53.338614,
#   'longitude': -6.248606,
#   'timestamp': '2025-07-26T19:39:45.212816+00:00Z',
#   'free_bikes': 1,
#   'empty_slots': 38,
#   'extra': {'uid': 113,
#    'address': 'Merrion Square South',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:29:36Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 1}},
#  {'id': '745f937185c7bcec73ef007235d5583e',
#   'name': 'TALBOT STREET',
#   'latitude': 53.350974,
#   'longitude': -6.25294,
#   'timestamp': '2025-07-26T19:39:45.212919+00:00Z',
#   'free_bikes': 23,
#   'empty_slots': 17,
#   'extra': {'uid': 38,
#    'address': 'Talbot Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:29:59Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 13,
#    'normal_bikes': 10}},
#  {'id': '7480160ebd2b0de5cc9b7d0ca2265908',
#   'name': "ST. STEPHEN'S GREEN EAST",
#   'latitude': 53.337824,
#   'longitude': -6.256035,
#   'timestamp': '2025-07-26T19:39:45.213058+00:00Z',
#   'free_bikes': 34,
#   'empty_slots': 6,
#   'extra': {'uid': 36,
#    'address': "St. Stephen's Green East",
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:33:05Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 12,
#    'normal_bikes': 22}},
#  {'id': '76de76200b4558fdf5985cb25f1fe77e',
#   'name': 'GRAND CANAL DOCK',
#   'latitude': 53.342638,
#   'longitude': -6.238695,
#   'timestamp': '2025-07-26T19:39:45.213014+00:00Z',
#   'free_bikes': 5,
#   'empty_slots': 35,
#   'extra': {'uid': 69,
#    'address': 'Grand Canal Dock',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:28Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 2,
#    'normal_bikes': 3}},
#  {'id': '79c65939a9c632806dcecebc48275944',
#   'name': 'MOUNTJOY SQUARE WEST',
#   'latitude': 53.356299,
#   'longitude': -6.258586,
#   'timestamp': '2025-07-26T19:39:45.213244+00:00Z',
#   'free_bikes': 1,
#   'empty_slots': 29,
#   'extra': {'uid': 28,
#    'address': 'Mountjoy Square West',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:36Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 1}},
#  {'id': '7a78649dff82a724a790100242faf612',
#   'name': 'FREDERICK STREET SOUTH',
#   'latitude': 53.341515,
#   'longitude': -6.256853,
#   'timestamp': '2025-07-26T19:39:45.212722+00:00Z',
#   'free_bikes': 27,
#   'empty_slots': 13,
#   'extra': {'uid': 98,
#    'address': 'Frederick Street South',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:56Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 2,
#    'normal_bikes': 25}},
#  {'id': '8470b267289682681a65613b3732265a',
#   'name': 'BARROW STREET',
#   'latitude': 53.338311,
#   'longitude': -6.236779,
#   'timestamp': '2025-07-26T19:39:45.213232+00:00Z',
#   'free_bikes': 16,
#   'empty_slots': 5,
#   'extra': {'uid': 70,
#    'address': 'Barrow Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:31Z',
#    'slots': 21,
#    'has_ebikes': True,
#    'ebikes': 4,
#    'normal_bikes': 12}},
#  {'id': '85892a5c607e9d8c748b26e74f3a5db2',
#   'name': 'GOLDEN LANE',
#   'latitude': 53.340803,
#   'longitude': -6.267732,
#   'timestamp': '2025-07-26T19:39:45.212789+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 20,
#   'extra': {'uid': 17,
#    'address': 'Golden Lane',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:58Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': '879c05e967e65c50e8121f8e41699bd1',
#   'name': 'MERRION SQUARE WEST',
#   'latitude': 53.339764,
#   'longitude': -6.251988,
#   'timestamp': '2025-07-26T19:39:45.213118+00:00Z',
#   'free_bikes': 15,
#   'empty_slots': 5,
#   'extra': {'uid': 26,
#    'address': 'Merrion Square West',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:48Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 7,
#    'normal_bikes': 8}},
#  {'id': '8aadbf40c946051429ab75543f009e29',
#   'name': 'MOUNT BROWN',
#   'latitude': 53.341645,
#   'longitude': -6.29719,
#   'timestamp': '2025-07-26T19:39:45.212992+00:00Z',
#   'free_bikes': 2,
#   'empty_slots': 20,
#   'extra': {'uid': 82,
#    'address': 'Mount Brown',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:28Z',
#    'slots': 22,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 2}},
#  {'id': '8cd8770c3500b58e05c65dca076a00ac',
#   'name': 'CHRISTCHURCH PLACE',
#   'latitude': 53.343368,
#   'longitude': -6.27012,
#   'timestamp': '2025-07-26T19:39:45.212677+00:00Z',
#   'free_bikes': 16,
#   'empty_slots': 4,
#   'extra': {'uid': 6,
#    'address': 'Christchurch Place',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:11Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 4,
#    'normal_bikes': 12}},
#  {'id': '8dc250e10f6b800ab66807db4fcec02b',
#   'name': 'HEUSTON BRIDGE (SOUTH)',
#   'latitude': 53.347106,
#   'longitude': -6.292041,
#   'timestamp': '2025-07-26T19:39:45.213151+00:00Z',
#   'free_bikes': 24,
#   'empty_slots': 1,
#   'extra': {'uid': 100,
#    'address': 'Heuston Bridge (South)',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:31:16Z',
#    'slots': 25,
#    'has_ebikes': True,
#    'ebikes': 15,
#    'normal_bikes': 9}},
#  {'id': '91dfa0e55f92403e93f25d1aab411b7c',
#   'name': 'FOWNES STREET UPPER',
#   'latitude': 53.344603,
#   'longitude': -6.263371,
#   'timestamp': '2025-07-26T19:39:45.212728+00:00Z',
#   'free_bikes': 30,
#   'empty_slots': 0,
#   'extra': {'uid': 14,
#    'address': 'Fownes Street Upper',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:15Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 8,
#    'normal_bikes': 22}},
#  {'id': '948327418119a9fbf5fec754db7dc5df',
#   'name': 'GREEK STREET',
#   'latitude': 53.346874,
#   'longitude': -6.272976,
#   'timestamp': '2025-07-26T19:39:45.212886+00:00Z',
#   'free_bikes': 8,
#   'empty_slots': 12,
#   'extra': {'uid': 4,
#    'address': 'Greek Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:54Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 5,
#    'normal_bikes': 3}},
#  {'id': '95b25abb14351ba18840c307f9af37cc',
#   'name': 'GRANTHAM STREET',
#   'latitude': 53.334123,
#   'longitude': -6.265436,
#   'timestamp': '2025-07-26T19:39:45.212682+00:00Z',
#   'free_bikes': 3,
#   'empty_slots': 27,
#   'extra': {'uid': 18,
#    'address': 'Grantham Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:51Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 3}},
#  {'id': '96c377e929ac4d83561b0efb7ed48910',
#   'name': 'WILTON TERRACE',
#   'latitude': 53.332383,
#   'longitude': -6.252717,
#   'timestamp': '2025-07-26T19:39:45.213249+00:00Z',
#   'free_bikes': 14,
#   'empty_slots': 6,
#   'extra': {'uid': 39,
#    'address': 'Wilton Terrace',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:26Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 4,
#    'normal_bikes': 10}},
#  {'id': '98695c12cf569bff19abcdc0bbdf9cdb',
#   'name': 'WILTON TERRACE (PARK)',
#   'latitude': 53.333653,
#   'longitude': -6.248345,
#   'timestamp': '2025-07-26T19:39:45.212800+00:00Z',
#   'free_bikes': 12,
#   'empty_slots': 28,
#   'extra': {'uid': 114,
#    'address': 'Wilton Terrace (Park)',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:33Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 2,
#    'normal_bikes': 10}},
#  {'id': '98efd5ef2d9832e32fa341c6f4e39889',
#   'name': 'DEVERELL PLACE',
#   'latitude': 53.351464,
#   'longitude': -6.255265,
#   'timestamp': '2025-07-26T19:39:45.212795+00:00Z',
#   'free_bikes': 22,
#   'empty_slots': 8,
#   'extra': {'uid': 45,
#    'address': 'Deverell Place',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:30:56Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 19,
#    'normal_bikes': 3}},
#  {'id': '9a3222d1d49bec4b46fe2fc24720ac56',
#   'name': 'PHIBSBOROUGH ROAD',
#   'latitude': 53.356307,
#   'longitude': -6.273717,
#   'timestamp': '2025-07-26T19:39:45.213080+00:00Z',
#   'free_bikes': 3,
#   'empty_slots': 37,
#   'extra': {'uid': 110,
#    'address': 'Phibsborough Road',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:37Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 3}},
#  {'id': '9befbe579535b21b26fe97729b9aaa3a',
#   'name': 'RATHDOWN ROAD',
#   'latitude': 53.35893,
#   'longitude': -6.280337,
#   'timestamp': '2025-07-26T19:39:45.212745+00:00Z',
#   'free_bikes': 2,
#   'empty_slots': 38,
#   'extra': {'uid': 106,
#    'address': 'Rathdown Road',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:33:51Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 2}},
#  {'id': 'a2528349192a64f5841d6d5beaac8285',
#   'name': 'LIME STREET',
#   'latitude': 53.346026,
#   'longitude': -6.243576,
#   'timestamp': '2025-07-26T19:39:45.212854+00:00Z',
#   'free_bikes': 5,
#   'empty_slots': 35,
#   'extra': {'uid': 62,
#    'address': 'Lime Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:28Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 1,
#    'normal_bikes': 4}},
#  {'id': 'a2da0ed146cbbdd49885f0858d7fa923',
#   'name': 'HARDWICKE STREET',
#   'latitude': 53.355473,
#   'longitude': -6.264423,
#   'timestamp': '2025-07-26T19:39:45.213129+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 16,
#   'extra': {'uid': 15,
#    'address': 'Hardwicke Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:42Z',
#    'slots': 16,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': 'a5ffb884201a84d6f1cd6fe434170984',
#   'name': 'HERBERT STREET',
#   'latitude': 53.335742,
#   'longitude': -6.24551,
#   'timestamp': '2025-07-26T19:39:45.212958+00:00Z',
#   'free_bikes': 3,
#   'empty_slots': 37,
#   'extra': {'uid': 47,
#    'address': 'Herbert Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:04Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 2,
#    'normal_bikes': 1}},
#  {'id': 'a6ac5cbdfa374eb1a4ace9e65d8b7939',
#   'name': 'BUCKINGHAM STREET LOWER',
#   'latitude': 53.353331,
#   'longitude': -6.249319,
#   'timestamp': '2025-07-26T19:39:45.213168+00:00Z',
#   'free_bikes': 21,
#   'empty_slots': 7,
#   'extra': {'uid': 109,
#    'address': 'Buckingham Street Lower',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:10Z',
#    'slots': 29,
#    'has_ebikes': True,
#    'ebikes': 10,
#    'normal_bikes': 11}},
#  {'id': 'a829cb901d24566f0610a5874342349d',
#   'name': 'UPPER SHERRARD STREET',
#   'latitude': 53.358437,
#   'longitude': -6.260641,
#   'timestamp': '2025-07-26T19:39:45.213190+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 30,
#   'extra': {'uid': 44,
#    'address': 'Upper Sherrard Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:40Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': 'aa9dd743c0057f1898341bab187b68fc',
#   'name': 'SMITHFIELD NORTH',
#   'latitude': 53.349562,
#   'longitude': -6.278198,
#   'timestamp': '2025-07-26T19:39:45.212625+00:00Z',
#   'free_bikes': 20,
#   'empty_slots': 10,
#   'extra': {'uid': 42,
#    'address': 'Smithfield North',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:43Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 9,
#    'normal_bikes': 11}},
#  {'id': 'ab7d72d5a8ea1d870f8ccae6852b5dc6',
#   'name': 'KILMAINHAM GAOL',
#   'latitude': 53.342113,
#   'longitude': -6.310015,
#   'timestamp': '2025-07-26T19:39:45.212864+00:00Z',
#   'free_bikes': 31,
#   'empty_slots': 9,
#   'extra': {'uid': 97,
#    'address': 'Kilmainham Gaol',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:45Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 18,
#    'normal_bikes': 13}},
#  {'id': 'ada935c92adf2369d92391d9fb5398fb',
#   'name': 'MATER HOSPITAL',
#   'latitude': 53.359967,
#   'longitude': -6.264828,
#   'timestamp': '2025-07-26T19:39:45.213097+00:00Z',
#   'free_bikes': 4,
#   'empty_slots': 36,
#   'extra': {'uid': 78,
#    'address': 'Mater Hospital',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:18Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 3,
#    'normal_bikes': 1}},
#  {'id': 'b0c26d04d6812062b8d48e87eeec5407',
#   'name': 'NEW CENTRAL BANK',
#   'latitude': 53.347122,
#   'longitude': -6.234749,
#   'timestamp': '2025-07-26T19:39:45.212936+00:00Z',
#   'free_bikes': 7,
#   'empty_slots': 33,
#   'extra': {'uid': 66,
#    'address': 'New Central Bank',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:49Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 3,
#    'normal_bikes': 4}},
#  {'id': 'b1c774f178240d5d757854364dafc840',
#   'name': 'FENIAN STREET',
#   'latitude': 53.341428,
#   'longitude': -6.24672,
#   'timestamp': '2025-07-26T19:39:45.212811+00:00Z',
#   'free_bikes': 11,
#   'empty_slots': 24,
#   'extra': {'uid': 63,
#    'address': 'Fenian Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:30Z',
#    'slots': 35,
#    'has_ebikes': True,
#    'ebikes': 4,
#    'normal_bikes': 7}},
#  {'id': 'b1c790286e760185c240642d01f05b78',
#   'name': 'ORMOND QUAY UPPER',
#   'latitude': 53.346057,
#   'longitude': -6.268001,
#   'timestamp': '2025-07-26T19:39:45.213227+00:00Z',
#   'free_bikes': 28,
#   'empty_slots': 1,
#   'extra': {'uid': 29,
#    'address': 'Ormond Quay Upper',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:29Z',
#    'slots': 29,
#    'has_ebikes': True,
#    'ebikes': 14,
#    'normal_bikes': 14}},
#  {'id': 'ba200d004f519056c7c22174689a353d',
#   'name': 'OLIVER BOND STREET',
#   'latitude': 53.343893,
#   'longitude': -6.280531,
#   'timestamp': '2025-07-26T19:39:45.212761+00:00Z',
#   'free_bikes': 17,
#   'empty_slots': 13,
#   'extra': {'uid': 74,
#    'address': 'Oliver Bond Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:34Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 7,
#    'normal_bikes': 10}},
#  {'id': 'bc84f752c0329ba197f92110262951d3',
#   'name': 'BLACKHALL PLACE',
#   'latitude': 53.3488,
#   'longitude': -6.281637,
#   'timestamp': '2025-07-26T19:39:45.213270+00:00Z',
#   'free_bikes': 3,
#   'empty_slots': 27,
#   'extra': {'uid': 88,
#    'address': 'Blackhall Place',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:45Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 1,
#    'normal_bikes': 2}},
#  {'id': 'bca80581dac58915734223afb6f9d18a',
#   'name': 'NEWMAN HOUSE',
#   'latitude': 53.337132,
#   'longitude': -6.26059,
#   'timestamp': '2025-07-26T19:39:45.212924+00:00Z',
#   'free_bikes': 12,
#   'empty_slots': 28,
#   'extra': {'uid': 53,
#    'address': 'Newman House',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:39Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 1,
#    'normal_bikes': 11}},
#  {'id': 'bd6828e2b768939185404e89537ab131',
#   'name': 'COLLINS BARRACKS MUSEUM',
#   'latitude': 53.347477,
#   'longitude': -6.28525,
#   'timestamp': '2025-07-26T19:39:45.212767+00:00Z',
#   'free_bikes': 24,
#   'empty_slots': 14,
#   'extra': {'uid': 87,
#    'address': 'Collins Barracks Museum',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:30Z',
#    'slots': 38,
#    'has_ebikes': True,
#    'ebikes': 8,
#    'normal_bikes': 16}},
#  {'id': 'bf6b75f2039b2b974a61b0f7ec1fe12f',
#   'name': "ST. STEPHEN'S GREEN SOUTH",
#   'latitude': 53.337494,
#   'longitude': -6.26199,
#   'timestamp': '2025-07-26T19:39:45.213031+00:00Z',
#   'free_bikes': 8,
#   'empty_slots': 22,
#   'extra': {'uid': 37,
#    'address': "St. Stephen's Green South",
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:35:44Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 3,
#    'normal_bikes': 5}},
#  {'id': 'bf826dd5e8d580728a8927ef7fe25bf9',
#   'name': 'CATHAL BRUGHA STREET',
#   'latitude': 53.352149,
#   'longitude': -6.260533,
#   'timestamp': '2025-07-26T19:39:45.213157+00:00Z',
#   'free_bikes': 20,
#   'empty_slots': 0,
#   'extra': {'uid': 24,
#    'address': 'Cathal Brugha Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:34Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 10,
#    'normal_bikes': 10}},
#  {'id': 'c0eb1d097e6980bb8b91c2aee34d28c1',
#   'name': 'CUSTOM HOUSE',
#   'latitude': 53.348279,
#   'longitude': -6.254662,
#   'timestamp': '2025-07-26T19:39:45.212739+00:00Z',
#   'free_bikes': 14,
#   'empty_slots': 16,
#   'extra': {'uid': 23,
#    'address': 'Custom House',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:08Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 8,
#    'normal_bikes': 6}},
#  {'id': 'c69463d2b93dfe6d264028658d7355da',
#   'name': 'GUILD STREET',
#   'latitude': 53.347932,
#   'longitude': -6.240928,
#   'timestamp': '2025-07-26T19:39:45.212892+00:00Z',
#   'free_bikes': 5,
#   'empty_slots': 35,
#   'extra': {'uid': 49,
#    'address': 'Guild Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:13Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 1,
#    'normal_bikes': 4}},
#  {'id': 'c6afbdf0e0873225c50674450c782afb',
#   'name': 'KEVIN STREET',
#   'latitude': 53.337757,
#   'longitude': -6.267699,
#   'timestamp': '2025-07-26T19:39:45.213003+00:00Z',
#   'free_bikes': 7,
#   'empty_slots': 33,
#   'extra': {'uid': 71,
#    'address': 'Kevin Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:20Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 3,
#    'normal_bikes': 4}},
#  {'id': 'c95abfb01cb256a25061f544fb13e2c8',
#   'name': 'EXCHEQUER STREET',
#   'latitude': 53.343034,
#   'longitude': -6.263578,
#   'timestamp': '2025-07-26T19:39:45.212832+00:00Z',
#   'free_bikes': 24,
#   'empty_slots': 0,
#   'extra': {'uid': 9,
#    'address': 'Exchequer Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:24Z',
#    'slots': 24,
#    'has_ebikes': True,
#    'ebikes': 6,
#    'normal_bikes': 18}},
#  {'id': 'cb86fbba9f73ec42274939110ddb845e',
#   'name': 'HATCH STREET',
#   'latitude': 53.33403,
#   'longitude': -6.260714,
#   'timestamp': '2025-07-26T19:39:45.212848+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 35,
#   'extra': {'uid': 55,
#    'address': 'Hatch Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:30:17Z',
#    'slots': 36,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': 'cbd6fb0ab33a7fdb706980585189da92',
#   'name': 'JERVIS STREET',
#   'latitude': 53.3483,
#   'longitude': -6.266651,
#   'timestamp': '2025-07-26T19:39:45.213222+00:00Z',
#   'free_bikes': 20,
#   'empty_slots': 1,
#   'extra': {'uid': 40,
#    'address': 'Jervis Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:28Z',
#    'slots': 21,
#    'has_ebikes': True,
#    'ebikes': 11,
#    'normal_bikes': 9}},
#  {'id': 'cda1c18c4d2056fb5beddd1c630e1ab0',
#   'name': 'ECCLES STREET',
#   'latitude': 53.359246,
#   'longitude': -6.269779,
#   'timestamp': '2025-07-26T19:39:45.213086+00:00Z',
#   'free_bikes': 2,
#   'empty_slots': 18,
#   'extra': {'uid': 12,
#    'address': 'Eccles Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:36Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 2}},
#  {'id': 'd259018d44d9783796099054d965f33a',
#   'name': 'ROYAL HOSPITAL',
#   'latitude': 53.343897,
#   'longitude': -6.29706,
#   'timestamp': '2025-07-26T19:39:45.213041+00:00Z',
#   'free_bikes': 22,
#   'empty_slots': 18,
#   'extra': {'uid': 95,
#    'address': 'Royal Hospital',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:55Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 3,
#    'normal_bikes': 19}},
#  {'id': 'd3ef511cdd49198b6e9c2f24c09c4a0d',
#   'name': 'WOLFE TONE STREET',
#   'latitude': 53.348875,
#   'longitude': -6.267459,
#   'timestamp': '2025-07-26T19:39:45.212875+00:00Z',
#   'free_bikes': 24,
#   'empty_slots': 5,
#   'extra': {'uid': 77,
#    'address': 'Wolfe Tone Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:48Z',
#    'slots': 29,
#    'has_ebikes': True,
#    'ebikes': 9,
#    'normal_bikes': 15}},
#  {'id': 'da5ec52b97e932d1a68cb96164879bf6',
#   'name': 'MARKET STREET SOUTH',
#   'latitude': 53.342296,
#   'longitude': -6.287661,
#   'timestamp': '2025-07-26T19:39:45.212997+00:00Z',
#   'free_bikes': 5,
#   'empty_slots': 33,
#   'extra': {'uid': 76,
#    'address': 'Market Street South',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:19Z',
#    'slots': 38,
#    'has_ebikes': True,
#    'ebikes': 1,
#    'normal_bikes': 4}},
#  {'id': 'da5ff1f0e055a61cdbd2cfa4304e6d35',
#   'name': 'CONVENTION CENTRE',
#   'latitude': 53.34744,
#   'longitude': -6.238523,
#   'timestamp': '2025-07-26T19:39:45.213124+00:00Z',
#   'free_bikes': 6,
#   'empty_slots': 34,
#   'extra': {'uid': 65,
#    'address': 'Convention Centre',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:31:14Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 2,
#    'normal_bikes': 4}},
#  {'id': 'e24d1c306b1d65ad507083c305c709dc',
#   'name': 'PORTOBELLO ROAD',
#   'latitude': 53.330091,
#   'longitude': -6.268044,
#   'timestamp': '2025-07-26T19:39:45.212712+00:00Z',
#   'free_bikes': 10,
#   'empty_slots': 20,
#   'extra': {'uid': 43,
#    'address': 'Portobello Road',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:22Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 2,
#    'normal_bikes': 8}},
#  {'id': 'e61ec9728297f73d6779e35ee766c892',
#   'name': "NORTH CIRCULAR ROAD (O'CONNELL'S)",
#   'latitude': 53.357841,
#   'longitude': -6.251557,
#   'timestamp': '2025-07-26T19:39:45.212750+00:00Z',
#   'free_bikes': 3,
#   'empty_slots': 27,
#   'extra': {'uid': 112,
#    'address': "North Circular Road (O'Connell's)",
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:18Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 3}},
#  {'id': 'e72b6d52782953a44ad36563c0d4ae6d',
#   'name': 'DENMARK STREET GREAT',
#   'latitude': 53.35561,
#   'longitude': -6.261397,
#   'timestamp': '2025-07-26T19:39:45.213036+00:00Z',
#   'free_bikes': 0,
#   'empty_slots': 20,
#   'extra': {'uid': 59,
#    'address': 'Denmark Street Great',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:34:53Z',
#    'slots': 20,
#    'has_ebikes': True,
#    'ebikes': 0,
#    'normal_bikes': 0}},
#  {'id': 'e8f23b591ae7a2afdfe06058eae28e66',
#   'name': 'HEUSTON STATION (CENTRAL)',
#   'latitude': 53.346603,
#   'longitude': -6.296924,
#   'timestamp': '2025-07-26T19:39:45.213063+00:00Z',
#   'free_bikes': 36,
#   'empty_slots': 4,
#   'extra': {'uid': 93,
#    'address': 'Heuston Station (Central)',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:35:57Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 13,
#    'normal_bikes': 23}},
#  {'id': 'ed74535aec51c7f285d982bd70b03c0d',
#   'name': 'HERBERT PLACE',
#   'latitude': 53.334432,
#   'longitude': -6.245575,
#   'timestamp': '2025-07-26T19:39:45.212897+00:00Z',
#   'free_bikes': 5,
#   'empty_slots': 25,
#   'extra': {'uid': 19,
#    'address': 'Herbert Place',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:43Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 1,
#    'normal_bikes': 4}},
#  {'id': 'f190fd9c0cb2e3d49326241e60254820',
#   'name': 'CHARLEVILLE ROAD',
#   'latitude': 53.359157,
#   'longitude': -6.281866,
#   'timestamp': '2025-07-26T19:39:45.213179+00:00Z',
#   'free_bikes': 11,
#   'empty_slots': 29,
#   'extra': {'uid': 107,
#    'address': 'Charleville Road',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:37:50Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 8,
#    'normal_bikes': 3}},
#  {'id': 'f1d78de0fc11dec4e7396d1cd0222172',
#   'name': 'JAMES STREET',
#   'latitude': 53.343456,
#   'longitude': -6.287409,
#   'timestamp': '2025-07-26T19:39:45.213107+00:00Z',
#   'free_bikes': 33,
#   'empty_slots': 7,
#   'extra': {'uid': 75,
#    'address': 'James Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:38:05Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 13,
#    'normal_bikes': 20}},
#  {'id': 'f4ba711dcc36d47f4801d26ebda44edd',
#   'name': 'SANDWITH STREET',
#   'latitude': 53.345203,
#   'longitude': -6.247163,
#   'timestamp': '2025-07-26T19:39:45.213163+00:00Z',
#   'free_bikes': 9,
#   'empty_slots': 31,
#   'extra': {'uid': 64,
#    'address': 'Sandwith Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:29:38Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 5,
#    'normal_bikes': 4}},
#  {'id': 'f5e210c0a5dcc2f14bf01589bc541d79',
#   'name': 'CUSTOM HOUSE QUAY',
#   'latitude': 53.347884,
#   'longitude': -6.248048,
#   'timestamp': '2025-07-26T19:39:45.212969+00:00Z',
#   'free_bikes': 16,
#   'empty_slots': 14,
#   'extra': {'uid': 8,
#    'address': 'Custom House Quay',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:39:37Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 3,
#    'normal_bikes': 13}},
#  {'id': 'f9bffc0c780d185d007102b425dfc7e1',
#   'name': 'HANOVER QUAY',
#   'latitude': 53.344115,
#   'longitude': -6.237153,
#   'timestamp': '2025-07-26T19:39:45.212756+00:00Z',
#   'free_bikes': 8,
#   'empty_slots': 32,
#   'extra': {'uid': 68,
#    'address': 'Hanover Quay',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:36:02Z',
#    'slots': 40,
#    'has_ebikes': True,
#    'ebikes': 6,
#    'normal_bikes': 2}},
#  {'id': 'feab4d3d1bc39c4102e073512c623cc9',
#   'name': 'KILLARNEY STREET',
#   'latitude': 53.354845,
#   'longitude': -6.247579,
#   'timestamp': '2025-07-26T19:39:45.212952+00:00Z',
#   'free_bikes': 15,
#   'empty_slots': 15,
#   'extra': {'uid': 115,
#    'address': 'Killarney Street',
#    'status': 'OPEN',
#    'banking': False,
#    'bonus': False,
#    'last_update': '2025-07-26T19:33:17Z',
#    'slots': 30,
#    'has_ebikes': True,
#    'ebikes': 5,
#    'normal_bikes': 10}}]

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
import pandas as pd

df_dublin = pd.DataFrame({
                          "names": names,
                          "latitude": latitude,
                          "longitude": longitude,
                          "num_bike_slots": num_bike_slots
                         })

df_dublin = df_dublin.set_index(['latitude','longitude']) # Assigning the coordinates as an index
df_dublin
# Out:
#                                                  names  num_bike_slots
# latitude  longitude
# 53.354929 -6.269425                        WESTERN WAY              40
# 53.349013 -6.260311  PRINCES STREET / O'CONNELL STREET              23
# 53.336074 -6.252825            FITZWILLIAM SQUARE WEST              30
# 53.351182 -6.269859                      BOLTON STREET              20
# 53.354663 -6.278681         GRANGEGORMAN LOWER (SOUTH)              40
# ...                                                ...             ...
# 53.343456 -6.287409                       JAMES STREET              40
# 53.345203 -6.247163                    SANDWITH STREET              40
# 53.347884 -6.248048                  CUSTOM HOUSE QUAY              30
# 53.344115 -6.237153                       HANOVER QUAY              40
# 53.354845 -6.247579                   KILLARNEY STREET              30
#
# [115 rows x 2 columns]

# %%
# Saving the df_dublin dataframe as .csv
df_dublin.to_csv('dublin_bikes.csv')
